# %%
import pandas as pd
import os, sys
from pathlib import Path


sys.path.append(os.path.abspath("../src"))

os.curdir

from project_data.load_project_files import pipeline

# %%
pipeline('Downtown Brooklyn, New York, USA')
# Out:
# INFO: Converting intersection graph to GeoDataFrames...
# INFO: Consolidating intersections...
# INFO: Done consolidating intersections.
# INFO: Done.
# Loading Feature Files..
# 	bike_rtes: Success!
# 	bus_lanes: Success!
# 	ped_plaza: Success!
# 	traffic_calming: Success!
# Cleaning Feature Files..
# 	bike_rtes: Fail! 'str' object is not callable
# 	bus_lanes: Fail! 'str' object is not callable
# 	ped_plaza: Fail! 'str' object is not callable
# 	traffic_calming: Fail! 'str' object is not callable
# /Users/jon/Documents/Employment/2025 VIDA Lab/nyc_street_design_adherence/src/projects/clean_feature_sourcefile.py:42: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return_gdf['installdate'] = pd.to_datetime(input_gdf['completion'])
# ...
